# %%
import os
import json

# %%
import pandas as pd
import numpy as np
import sqlite3

# %%
con = sqlite3.connect("database.sqlite")

# %%
# select emails sent to hillary clinton
df = pd.read_sql("select * from Emails e left join EmailReceivers r on e.Id = r.EmailId where r.PersonId=80", con)

# %%
len(df)
# Out:
# 5587

# %%
df.head()
# Out:
#   Id  DocNumber                                    MetadataSubject MetadataTo  \
# 0  1  C05739545                                                WOW          H
# 1  2  C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...          H
# 2  3  C05739547                                      CHRIS STEVENS         ;H
# 3  4  C05739550                         CAIRO CONDEMNATION - FINAL          H
# 4  7  C05739560  ANTI-MUSLIM FILM DIRECTOR IN HIDING, FOLLOWING...          H
#
#         MetadataFrom SenderPersonId           MetadataDateSent  \
# 0  Sullivan, Jacob J             87  2012-09-12T04:00:00+00:00
# 1                                    2011-03-03T05:00:00+00:00
# 2    Mills, Cheryl D             32  2012-09-12T04:00:00+00:00
# 3    Mills, Cheryl D             32  2012-09-12T04:00:00+00:00
# 4    Mills, Cheryl D             32  2012-09-12T04:00:00+00:00
#
#         MetadataDateReleased  \
# 0  2015-05-22T04:00:00+00:00
# 1  2015-05-22T04:00:00+00:00
# ...

# %%
export = []
for i, r in df.iterrows():
    if r['MetadataSubject'].strip() == "":
        subj = "<b>Subject:</b> none<br/>"
    else:
        subj = f"<b>Subject:</b> <i>{r['MetadataSubject'].strip()}</i><br/>"
    if r['ExtractedBodyText'].strip() == "":
        body = "<b>Body</b>: none<br/>"
    else:
        body = f"<b>Body</b>:<pre class='summary'>{r['ExtractedBodyText'].strip()}</pre><br/>"
    txt = f"{subj}{body}<b>RawText</b>:<pre>{r['RawText']}</pre>"
    export.append({"id": str(r['EmailId']), "data": {"text": txt, "docNumber": r['DocNumber'], "dbId": str(r['EmailId'])}})

# %%
output = json.dumps(export, indent=2)
with open('labelstudio_export.json', 'w') as f:
    f.write(output)

# %%
# !head labelstudio_export.json
# Out:
# [
#   {
#     "id": "1",
#     "data": {
# ...
